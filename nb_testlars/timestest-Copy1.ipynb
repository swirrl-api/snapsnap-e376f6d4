# %% [markdown]
# env list

# %%
remote_data = xr.open_dataset(

    "https://geoservices.knmi.nl/adagucopendap/HARM_N25%2FHARM_N25_202401012100.nc",

    decode_times=False,

)



remote_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 remote_data = xr.open_dataset(
#       2
#       3     "https://geoservices.knmi.nl/adagucopendap/HARM_N25%2FHARM_N25_202401012100.nc",
#       4
#       5     decode_times=False,
#       6
#       7 )
#      11 remote_data
#
# NameError: name 'xr' is not defined

# %%
pip install ecmwflibs
# Out:
# 4474.04s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install eccodes
# Out:
# 4481.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install eccodes --upgrade
# Out:
# 4488.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env ECCODES_DEFINITION_PATH='/home/jovyan/work/private/definitions:/usr/local/share/eccodes/definitions'
# Out:
# env: ECCODES_DEFINITION_PATH='/home/jovyan/work/private/definitions:/usr/local/share/eccodes/definitions'

# %%
 #!/usr/bin/python3

import numpy as np
import math
import datetime
import sys
import os
import xarray as xr
import re
import cfgrib

# plot modules
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.pyplot as plt
import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs

# %%
filename = '/home/jovyan/work/private/'

# %%
aap = cfgrib.open_dataset(filename+'HA40_N55_202401020600_01200_GB.grib', engine='cfgrib', filter_by_keys={'typeOfLevel': 'heightAboveSea', 'stepType': 'instant'})

# %%
aap
# Out:
# <xarray.Dataset>
# Dimensions:         (y: 340, x: 340)
# Coordinates:
#     time            datetime64[ns] ...
#     step            timedelta64[ns] ...
#     heightAboveSea  float64 ...
#     latitude        (y, x) float64 ...
#     longitude       (y, x) float64 ...
#     valid_time      datetime64[ns] ...
# Dimensions without coordinates: y, x
# Data variables:
#     unknown         (y, x) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             99
#     GRIB_centreDescription:  DeBilt, Netherlands
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             DeBilt, Netherlands
#     history:                 2024-01-02T15:36 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
aap = xr.open_dataset(filename+'HA40_N55_202401020600_01300_GB', engine='cfgrib', filter_by_keys={'typeOfLevel': 'heightAboveGround', 'stepType': 'instant', 'shortName': '3jklhkljhkl046'})

# %%
pip list
# Out:
# 1253.47s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Package                       Version
# ----------------------------- -----------
# affine                        2.4.0
# alembic                       1.11.1
# anyio                         3.6.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asttokens                     2.2.1
# async-generator               1.10
# async-lru                     2.0.2
# attrs                         23.1.0
# automap                       0.6.2
# Babel                         2.12.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.12.2
# bleach                        6.0.0
# blinker                       1.6.2
# boltons                       23.0.0
# branca                        0.6.0
# Cartopy                       0.22.0
# certifi                       2023.7.22
# ...

# %% [markdown]
# Just some testing
